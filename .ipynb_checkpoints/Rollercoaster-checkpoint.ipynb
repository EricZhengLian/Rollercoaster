# %%
import pandas as pd 
import numpy as np 
import datetime as dt 
import random 
import matplotlib.pyplot as plt 
import time
# %matplotlib inline

# %% [markdown]
# Read the file, strip the white columns and check the info.

# %%
rc = pd.read_csv('rollercoaster.csv')
rc.columns = rc.columns.str.strip()
rc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 20 columns):
# Name                        300 non-null object
# Park                        300 non-null object
# City/Region                 300 non-null object
# City/State/Region           300 non-null object
# Country/Region              300 non-null object
# Geographic Region           300 non-null object
# Construction                300 non-null object
# Type                        300 non-null object
# Status                      300 non-null object
# Year/Date Opened            300 non-null int64
# Height (feet)               299 non-null object
# Speed (mph)                 296 non-null float64
# Length (feet)               295 non-null float64
# Inversions (YES or NO)      300 non-null object
# Number of Inversions        300 non-null int64
# Drop (feet)                 142 non-null object
# Duration (min:sec)          224 non-null object
# G Force                     83 non-null object
# Vertical Angle (degrees)    91 non-null float64
# CoasterBuzz Ranking         69 non-null float64
# dtypes: float64(4), int64(2), object(14)
# memory usage: 47.0+ KB

# %%
rc.columns
# Out:
# Index(['Name', 'Park', 'City/Region', 'City/State/Region', 'Country/Region',
#        'Geographic Region', 'Construction', 'Type', 'Status',
#        'Year/Date Opened', 'Height (feet)', 'Speed (mph)', 'Length (feet)',
#        'Inversions (YES or NO)', 'Number of Inversions', 'Drop (feet)',
#        'Duration (min:sec)', 'G Force', 'Vertical Angle (degrees)',
#        'CoasterBuzz Ranking'],
#       dtype='object')

# %% [markdown]
# From the info report, we noticed that the columns "Drop(feet)", "G Force", "Vertical Angle (degrees)" and "CoasterBuzz Ranking" have fewer than half of the valuable data. So we decide to get rid of these columns.

# %%
rc_ranking = rc.drop(columns = ['Drop (feet)', 'G Force', 'Vertical Angle (degrees)'])
print(rc_ranking.info())
rc = rc_ranking.drop(columns = "CoasterBuzz Ranking")
print(rc.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 17 columns):
# Name                      300 non-null object
# Park                      300 non-null object
# City/Region               300 non-null object
# City/State/Region         300 non-null object
# Country/Region            300 non-null object
# Geographic Region         300 non-null object
# Construction              300 non-null object
# Type                      300 non-null object
# Status                    300 non-null object
# Year/Date Opened          300 non-null int64
# Height (feet)             299 non-null object
# Speed (mph)               296 non-null float64
# Length (feet)             295 non-null float64
# Inversions (YES or NO)    300 non-null object
# Number of Inversions      300 non-null int64
# Duration (min:sec)        224 non-null object
# CoasterBuzz Ranking       69 non-null float64
# dtypes: float64(3), int64(2), object(12)
# memory usage: 39.9+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 16 columns):
# Name                      300 non-null object
# Park                      300 non-null object
# City/Region               300 non-null object
# City/State/Region         300 non-null object
# Country/Region            300 non-null object
# Geographic Region         300 non-null object
# Construction              300 non-null object
# Type                      300 non-null object
# Status                    300 non-null object
# Year/Date Opened          300 non-null int64
# Height (feet)             299 non-null object
# Speed (mph)               296 non-null float64
# Length (feet)             295 non-null float64
# Inversions (YES or NO)    300 non-null object
# Number of Inversions      300 non-null int64
# Duration (min:sec)        224 non-null object
# dtypes: float64(2), int64(2), object(12)
# memory usage: 37.6+ KB
# None

# %%
# finding rows with missing values
rc[(rc['Height (feet)'].isnull() == True) | (rc['Speed (mph)'].isnull() == True) | (rc['Length (feet)'].isnull() == True) | (rc['Duration (min:sec)'].isnull() == True)]
# Out:
#                                  Name  \
# 2                     Adrenaline Peak
# 5                        Alpina Blitz
# 6                              Altair
# 28                           Behemoth
# 30                           Big Loop
# 35                        Black Mamba
# 39                   Boardwalk Bullet
# 40                           Bocaraca
# 51                               Boss
# 53                     Bullet Coaster
# 64                         Crazy Bird
# 65                      Crazy Coaster
# 73                          Dinoconda
# 74                         Do-Dodonpa
# 75                         Doble Loop
# 78                       Dragon's Run
# 81                            El Toro
# 84                     Extreme Rusher
# 94              Flight of the Phoenix
# 95                 Fluch von Novgorod
# 97                        Flying Aces
# 99                      Formula Rossa
# 103                          Fury 325
# 109                      Giant Dipper
# 111                           Goliath
# 114                           Goliath
# 117             Green Lantern Coaster
# 120                         Hades 360
# 122                       Happy Angel
# 126                     Hyper Coaster
# ..                                ...
# 202                        RailBlazer
# 203                       Ranier Rush
# 208                         Red Force
# 218                 Schwur des KŠrnan
# 228                           Skyrush
# 231  Soaring Dragon & Dancing Phoenix
# 236                     Star Mountain
# 238                           Stealth
# 243                       Steel Venom
# 247                     Super Tornado
# 256                         T Express
# 258                             Talon
# 259                             Taron
# 260                             Tatsu
# 264                     Texas Tornado
# 266                       Timber Drop
# 268          Timberhawk: Ride of Prey
# 271                    Titan Cascabel
# 274                           Tornado
# 277                        Twister II
# 278                          Ultimate
# 279             V2: Vertical Velocity
# 280                           Valravn
# 282     Velikolukskiy Myasokombinat-2
# 283                 Vertical Velocity
# 288        Whirl Wind Looping Coaster
# 290                    Wicked Cyclone
# 291                    Wicked Twister
# 296                            Winjas
# 298                                X2
#
#                                           Park       City/Region  \
# 2                          Oaks Amusement Park          Portland
# 5                                    Nigloland        Dolancourt
# 6                              Cinecittˆ World              Rome
# 28                         Canada's Wonderland           Vaughan
# 30                           Heide-Park Resort            Soltau
# 35                               Phantasialand            Bruhl
# 39                             Kemah Boardwalk             Kemah
# 40                      Parque de Diversiones           La Uruca
# 51                         Six Flags St. Louis            Eureka
# 53                                Happy Valley           Nanshan
# 64                                Happy Valley            Dongli
# 65                 Loca Joy Holiday Theme Park         Yongchuan
# 73                        China Dinosaurs Park            Xinbei
# 74                             Fuji-Q Highland       Fujiyoshida
# 75                              Salitre Magico            Bogota
# 78                                 Dragon Park           Ha Long
# 81                          Freizeitpark Plohn       Lengenfeld
# 84                                Happy Valley          Chaoyang
# 94                                  Harborland            Beilun
# 95                                  Hansa Park        Sierksdorf
# 97                     Ferrari World Abu Dhabi         Abu Dhabi
# 99                     Ferrari World Abu Dhabi         Abu Dhabi
# 103                                  Carowinds         Charlotte
# 109                               Belmont Park         San Diego
# 111                     Six Flags Over Georgia           Austell
# 114                    Six Flags Great America            Gurnee
# 117                   Warner Bros. Movie World        Gold Coast
# 120             Mt. Olympus Water & Theme Park   Wisconsin Dells
# 122                           Wanda Theme Park            Harbin
# 126                 Land of Legends Theme Park           Antalya
# ..                                         ...               ...
# 202                 California's Great America       Santa Clara
# 203                              Puyallup Fair          Puyallup
# 208                               Ferrari Land             Salou
# 283        Steel  Inverted   Operating              2001           185
# 288        Steel  Sit Down   Operating              2003            64
# 290        Steel  Sit Down   Operating              2015           109
# 291        Steel  Inverted   Operating              2002           215
# 296        Steel  Sit Down   Operating              2002          57.1
# 298        Steel      Wing   Operating              2002           175
#
#      Speed (mph)  Length (feet) Inversions (YES or NO)  Number of Inversions  \
# 2           45.0         1050.0                    YES                     3
# 5           51.6         2358.9                     NO                     0
# 6           52.8         2879.8                    YES                    10
# 28          77.0         5318.0                     NO                     0
# 30          39.2         2316.3                    YES                     4
# 35          49.7         2519.7                    YES                     4
# 39          51.0         3236.0                     NO                     0
# 40          37.3         1148.3                    YES                     2
# 51          66.3         4631.0                     NO                     0
# 53          83.0            NaN                     NO                     0
# 64           NaN         1279.5                    YES                     2
# 65          52.8         2870.8                    YES                    10
# 73          78.3         3444.9                    YES                     3
# 74         111.8         4081.3                    YES                     1
# 75          56.0         2822.0                    YES                     2
# 78          65.0         3738.0                    YES                     6
# 81          45.6         2379.0                     NO                     0
# 84          83.0         2788.8                     NO                     0
# 94          49.7         2723.1                    YES                     8
# 95          62.1         2296.6                    YES                     1
# 97          74.6         4921.3                    YES                     1
# 99         149.1         6561.7                     NO                     0
# 103         95.0         6602.0                     NO                     0
# 109         55.0         2600.0                     NO                     0
# 111         70.0         4480.0                     NO                     0
# 114         72.0         3100.0                    YES                     2
# 117         41.0         1601.1                    YES                     2
# 120         60.0         4746.0                    YES                     1
# 122         54.1            NaN                    YES                     6
# 126         71.5         4176.5                    YES                     2
# ..           ...            ...                    ...                   ...
# 202         52.0         1800.0                    YES                     3
# 203         45.0         1775.0                    YES                     1
# 208        111.8         2887.2                     NO                     0
# 218         78.9         4051.8                    YES                     1
# 228         75.0         3600.0                     NO                     0
# 231         84.0         4192.0                    YES                     6
# 236         40.0         2400.0                    YES                     2
# 238         80.0         1312.3                     NO                     0
# 243         68.0          630.0                     NO                     0
# 247         37.3         1148.3                    YES                     2
# 256         64.6         5383.8                     NO                     0
# 258         58.0         3110.0                    YES                     4
# 259         72.7         4330.8                     NO                     0
# 260         62.0         3602.0                    YES                     4
# 264         65.0         2050.0                    YES                     2
# 266         41.0            NaN                    YES                     2
# 268         50.0         2600.0                     NO                     0
# 271         55.0         2500.0                     NO                     0
# 274         37.3         1148.3                    YES                     2
# 277         55.0         4640.0                     NO                     0
# 278         50.0         7442.0                     NO                     0
# 279         65.0          630.0                     NO                     0
# 280         75.0         3415.0                    YES                     3
# 282         52.8         2870.0                    YES                    10
# 283         70.0          630.0                     NO                     0
# 288         37.3         1148.0                    YES                     2
# 290         55.0         3320.0                    YES                     3
# 291         72.0          215.0                     NO                     0
# 296         41.0         1526.6                     NO                     0
# 298         76.0         3610.0                    YES                     2
#
#     Duration (min:sec)
# 2                  NaN
# 5                  NaN
# 6                  NaN
# 28                 NaN
# 30                 NaN
# 35                 NaN
# 39                 NaN
# 40                 NaN
# 51                 NaN
# 53                 NaN
# 64                 NaN
# 65                 NaN
# 73                 NaN
# 74                 NaN
# 75                 NaN
# 78                 NaN
# 81                 NaN
# 84                 NaN
# 94                 NaN
# 95                 NaN
# 97                 NaN
# 99                 NaN
# 103                NaN
# 109                NaN
# 111                NaN
# 114                NaN
# 117                NaN
# 120                NaN
# 122                NaN
# 126                NaN
# ..                 ...
# 202                NaN
# 203                NaN
# 208                NaN
# 218                NaN
# 228                NaN
# 231                NaN
# 236                NaN
# 238                NaN
# 243                NaN
# 247                NaN
# 256                NaN
# 258                NaN
# 259                NaN
# 260                NaN
# 264                NaN
# 266               1:20
# 268                NaN
# 271                NaN
# 274                NaN
# 277                NaN
# 278                NaN
# 279                NaN
# 280                NaN
# 282                NaN
# 283                NaN
# 288                NaN
# 290                NaN
# 291                NaN
# 296                NaN
# 298                NaN
#
# [80 rows x 16 columns]

# %%
for i in range(len(rc)):
    try:
        float(rc['Height (feet)'][i])
    except:
        print(i, rc['Height (feet)'][i])
# Out:
# 111 200 ft

# %%
rc.loc[111, 'Height (feet)'] = 200
rc.iloc[111]
# Out:
# Name                                     Goliath
# Park                      Six Flags Over Georgia
# City/Region                              Austell
# City/State/Region                        Georgia
# Country/Region                     United States
# Geographic Region                  North America
# Construction                               Steel
# Type                                    Sit Down
# Status                                Operating
# Year/Date Opened                            2006
# Height (feet)                                200
# Speed (mph)                                   70
# Length (feet)                               4480
# Inversions (YES or NO)                        NO
# Number of Inversions                           0
# Duration (min:sec)                           NaN
# Name: 111, dtype: object

# %% [markdown]
# We want to fill in the NaN values with the mean of their corresponding columns.

# %%
#rc['Duration (min:sec)'] = rc['Duration (min:sec)'].replace(r'^\s+$', np.nan, regex=True)
#rc['Duration (min:sec)'] = pd.to_datetime(rc['Duration (min:sec)'])
#rc['Duration (min:sec)'].min

# %%
rc['Speed (mph)'].fillna((rc['Speed (mph)'].mean()),inplace = True)
rc['Length (feet)'].fillna((rc['Length (feet)'].mean()),inplace = True)
rc['Height (feet)'] = rc['Height (feet)'].astype(float)
rc['Height (feet)'].fillna((rc['Height (feet)'].mean()),inplace = True)
#rc[rc['Duration (min:sec)'].isnull() == False]['Duration (min:sec)'] = pd.to_datetime(rc[rc['Duration (min:sec)'].isnull() == False]['Duration (min:sec)'])


#rc['Duration (min:sec)'] = rc['Duration (min:sec)'].replace(r'^\s+$', np.nan, regex=True)

for m in range(len(rc)):
    try:
        value = rc['Duration (min:sec)'][m].split(':')
        i = 60
        total_sec = 0
        for numbers in value:
            total_sec += i*int(numbers)
            i = 1
        rc.loc[m, 'Duration (min:sec)'] = int(total_sec)
    except:
        pass

rc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 16 columns):
# Name                      300 non-null object
# Park                      300 non-null object
# City/Region               300 non-null object
# City/State/Region         300 non-null object
# Country/Region            300 non-null object
# Geographic Region         300 non-null object
# Construction              300 non-null object
# Type                      300 non-null object
# Status                    300 non-null object
# Year/Date Opened          300 non-null int64
# Height (feet)             300 non-null float64
# Speed (mph)               300 non-null float64
# Length (feet)             300 non-null float64
# Inversions (YES or NO)    300 non-null object
# Number of Inversions      300 non-null int64
# Duration (min:sec)        223 non-null float64
# dtypes: float64(4), int64(2), object(10)
# memory usage: 37.6+ KB
